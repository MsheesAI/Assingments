# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
salary = float(input("enter your salary: "))
years = float(input("enter your years of service: "))

if years > 5:
    bonus = salary * 0.05
    amount = salary + bonus
    print(f"bonus Amount: {bonus}")
    print(f"amount with Bonus: {amount}")
else:
    amount = salary
    print("You are not eligible for a bonus.")
    print(f"Net Salary: {amount}")
# Out:
# bonus Amount: 4500.0
# amount with Bonus: 94500.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
user_age = int(input("Enter your age"))
if (user_age >=17):
  print("eligible")
else:
  print("not eligible")
# Out:
# eligible

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
number = int(input("enter your integer number: "))
if (number/2==0):
  print(number,"is even")
else:
  print(number,"is odd")

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
num = 7
if(num/7 ==1):
  print("the number is divisable by 7")
else:
  print("number is not divisable by 7")

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
n = int(input("Enter a number which is divisable by 5 "))
if(n%5 ==0):
  print("hello")
else:
  print("Bye")

# %% [markdown]
# 6. Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length = float(input("Enter the length: "))
breadth = float(input("Enter the breadth: "))

if length == breadth:
    print("This is a Square.")
else:
    print("This is a Rectangle.")

# %% [markdown]
# 7. Take two int values from user and print greatest among them.

# %%
int_1 = int(input("Enter integer number one "))
int_2 = int(input("Enter integer number two "))

if int_1 > int_2 :
  print(int_1,"is greater than",int_2)
else:
  print(int_2,"is greater than",int_1)

# %% [markdown]
# 8. A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks_input = int(input("Enter your marks "))

if marks_input >80:
  print("A")
elif marks_input >=60:
  print("B")
elif marks_input >=50:
  print("C")
elif marks_input >=45:
  print("D")
elif marks_input >=25:
  print("E")
else:
  print("F")

# %% [markdown]
# 9. Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age = int(input("Enter Your Age: "))
gender =input("Enter Your Gender (M/F):").lower().strip()
marital_status = input("Enter Your Marital Status (Y/N):").lower().strip()

if marital_status == "y":
  print("You select Yes in martial status")
elif marital_status == "n":
  print("You select No in martial status")
else:
  print("Invalid Input.Choose between Y or N")

if gender == "m":
  print("You select Male")
elif gender == "f":
  print("You select Female")
else:
  print("Invalid Input.Choose between M or F")

if gender == "f":
    print("She can work only in Urban Areas")

elif gender == "m" and 20 <= age <= 40:
    print("He may work anywhere")

elif gender == "m" and 40 < age <= 60:
    print("He will work only in Urban Areas")

else:
    print("ERROR")
# Out:
# You select No
# You select Male
# He may work anywhere
